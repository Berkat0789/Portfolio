# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %%
data = pd.read_excel("resources/nasdaq_100_stocks.xlsx")

# %%
tickers = list(data["Ticker"])

# %%
len(tickers)
# Out:
# 103

# %%
nasdaq_df = pd.DataFrame()

# %%
failed = []
passed = []
for x in tickers:
    try:
        nasdaq_df[x] = web.DataReader(x, data_source= "yahoo", start = "2020-1-1")["Adj Close"]
        passed.append(x)
    except (IOError, KeyError):
        msg = 'Failed to read symbol: {0!r}, replacing with NaN.'
        failed.append(x)

# %%
nasdaq_df
# Out:
#                   AAL        AAPL  ...        XEL        XLNX
# Date                               ...
# 2020-01-02  28.982893  298.829956  ...  61.569065  100.765846
# 2020-01-03  27.548195  295.924713  ...  61.865166   98.446198
# 2020-01-06  27.219410  298.282715  ...  61.776337   96.394203
# 2020-01-07  27.119778  296.879883  ...  61.648026   98.594894
# 2020-01-08  27.737495  301.655548  ...  61.588806   98.317329
# ...               ...         ...  ...        ...         ...
# 2020-06-08  20.309999  333.459991  ...  66.507645   96.540001
# 2020-06-09  18.549999  343.989990  ...  65.931480   95.830002
# 2020-06-10  17.020000  352.839996  ...  66.487778   95.300003
# 2020-06-11  14.380000  335.899994  ...  64.650002   89.739998
# 2020-06-12  16.740000  338.799988  ...  63.650002   90.699997
#
# [113 rows x 100 columns]
