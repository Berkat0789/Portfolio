# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_datareader import data as web
# Out:
# /Users/berkatbhatti/opt/anaconda3/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
penny = pd.read_csv("resources/penny_stocks_under10.csv", index_col="Date")

# %%
penny_tickers = list(penny.columns)

# %%
pennyFrame = pd.DataFrame()

# %%
penny_tickers
# Out:
# ['ABEO',
#  'ACER',
#  'ACOR',
#  'ACRS',
#  'ACRX',
#  'ACTG',
#  'ADMA',
#  'ADMS',
#  'ADRO',
#  'AFI',
#  'AFMD',
#  'AGE',
#  'AGEN',
#  'AGLE',
#  'AHT',
#  'AI',
#  'AKTS',
#  'ALDX',
#  'ALTM',
#  'AMC',
#  'AMRS',
#  'AMRX',
#  'AMSC',
#  'ANH',
#  'APYX',
#  'ARA',
#  'ARAY',
#  'ARDX',
#  'ARLO',
#  'AROC',
#  'ASC',
#  'ASNA',
#  'ASRT',
#  'AT',
#  'ATEC',
#  'ATEN',
#  'ATHX',
#  'ATRS',
#  'AVCO',
#  'AVID',
#  'AVXL',
#  'AXAS',
#  'AXLA',
#  'AXTI',
#  'BBCP',
#  'BBX',
#  'BCOV',
#  'BCRX',
#  'BDSI',
#  'BGG',
#  'BHR',
#  'BKD',
#  'BNED',
#  'BRY',
#  'CALA',
#  'CASA',
#  'CASI',
#  'CBAY',
#  'CBL',
#  'CCO',
#  'CDE',
#  'CDMO',
#  'CDR',
#  'CDXC',
#  'CECE',
#  'CELH',
#  'CENX',
#  'CERC',
#  'CERS',
#  'CETV',
#  'CFMS',
#  'CHAP',
#  'CHMA',
#  'CHRA',
#  'CHS',
#  'CIA',
#  'CKPT',
#  'CLF',
#  'CLNE',
#  'CLXT',
#  'CMBM',
#  'CMO',
#  'CMRX',
#  'CNDT',
#  'CNR',
#  'CNSL',
#  'CNTY',
#  'CODA',
#  'CPE',
#  'CPRX',
#  'CRBP',
#  'CRK',
#  'CRMD',
# ...

# %%
passed = []
failed = []
for x in penny_tickers:
    try:
        pennyFrame[x] = web.DataReader(x, data_source="yahoo", start = "2020-9-1")["Adj Close"]
        passed.append(x)
    except(IOError, KeyError):
        failed.append(x)

# %%
pennyFrame.loc
# Out:
#             ABEO  ACER  ACOR  ACRS  ACRX  ACTG   ADMA   ADMS   AFI  AFMD  ...  \
# Date                                                                      ...
# 2020-09-01  2.35  2.64  0.53  2.33  1.24  3.82  2.400  5.120  3.95  3.46  ...
# 2020-09-02  2.16  2.63  0.52  2.35  1.23  3.82  2.280  5.280  3.75  3.52  ...
# 2020-09-03  2.05  2.55  0.52  2.22  1.15  3.75  2.230  5.430  3.57  3.39  ...
# 2020-09-04  1.98  2.44  0.48  2.14  1.15  3.80  2.220  5.370  3.55  3.28  ...
# 2020-09-08  2.08  2.31  0.48  2.03  1.11  3.69  2.285  5.120  3.75  3.28  ...
# 2020-09-09  2.03  2.33  0.46  2.15  1.15  3.82  2.210  5.230  3.83  3.38  ...
# 2020-09-10  2.04  2.28  0.47  2.19  1.09  3.82  2.280  5.060  3.80  3.41  ...
# 2020-09-11  1.92  2.16  0.45  2.16  1.07  3.76  2.240  4.300  3.74  3.43  ...
# 2020-09-14  1.99  2.45  0.45  2.23  1.26  3.79  2.370  4.340  3.90  3.60  ...
# 2020-09-15  2.01  2.47  0.51  2.35  1.22  3.79  2.340  4.310  3.85  3.58  ...
# ...

# %%
pd.DataFrame(pennyFrame.pct_change().loc["2020-09-25"]).sort_values("2020-09-25", ascending = False)
# Out:
#       2020-09-25
# ACOR    0.319149
# MOBL    0.198556
# NEXT    0.160448
# AXLA    0.143204
# IDEX    0.114943
# ...          ...
# FOSL   -0.074695
# CPE    -0.076190
# JILL   -0.087500
# SDRL   -0.088710
# TUSK   -0.145833
#
# [350 rows x 1 columns]
