# %% [markdown]
# ### Project Overview
#  - Your goal for thei project is to analyze the combine data provided
#  - You will look at for the following data
#
#  - Fastest 40 yard dash  over all and for a WR
#  - Fastest 40 yard dash for a RB
#  - tallest wide receiver over the 18 year span
#  - Who had the fastest shuttle drill for a RB

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("resources/nflcombine.csv", parse_dates = True)

# %% [markdown]
# ### Fastest 40 time
# - John Ross and Stallworth ties for a 4.22
# - Also looks as though John Ross was the fastest receiver since 2000

# %%
data.sort_values("Forty").head(5)
# Out:
#                  Player Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 5805          John Ross  WR  71  188   4.22      37.0        NaN      133.0
# 914   Donte' Stallworth  WR  72  197   4.22       NaN        NaN        NaN
# 2768      Chris Johnson  RB  71  197   4.24      35.0        NaN      130.0
# 4575         Dri Archer  WR  68  173   4.26      38.0       20.0      122.0
# 4332   Marquise Goodwin  WR  69  183   4.27       NaN       13.0      132.0
#
#       Cone  Shuttle  Year    Pfr_ID    AV                 Team  Round  Pick
# 5805   NaN      NaN  2017  RossJo00   0.0   Cincinnati Bengals    1.0   9.0
# 914    NaN      NaN  2002  StalDo00  19.0   New Orleans Saints    1.0  13.0
# 2768   NaN      NaN  2008  JohnCh04  43.0     Tennessee Titans    1.0  24.0
# 4575  6.86     4.06  2014  ArchDr00   0.0  Pittsburgh Steelers    3.0  97.0
# 4332   NaN      NaN  2013  GoodMa00   2.0        Buffalo Bills    3.0  78.0

# %% [markdown]
# ### 40 Time for a RB
# - Chris johnson hols the fastest forty time form 2000-2018, followed by keith marshall

# %%
data[data["Pos"] == 'RB'].sort_values("Forty").head(5)
# Out:
#                Player Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 2768    Chris Johnson  RB  71  197   4.24      35.0        NaN      130.0
# 5422   Keith Marshall  RB  71  219   4.31      30.5       25.0        NaN
# 3736  Taiwan Jones-01  RB  72  194   4.33       NaN       13.0        NaN
# 2802  Darren McFadden  RB  73  211   4.33      33.0        NaN      128.0
# 3173   Cedric Peerman  RB  69  216   4.34      40.0       27.0      117.0
#
#       Cone  Shuttle  Year    Pfr_ID    AV                 Team  Round   Pick
# 2768   NaN      NaN  2008  JohnCh04  43.0     Tennessee Titans    1.0   24.0
# 5422   NaN      NaN  2016  MarsKe00   0.0  Washington Redskins    7.0  242.0
# 3736   NaN      NaN  2011  JoneTa00   2.0      Oakland Raiders    4.0  125.0
# 2802   NaN      NaN  2008  McFaDa00  21.0      Oakland Raiders    1.0    4.0
# 3173  6.99     4.29  2009  PeerCe00   0.0     Baltimore Ravens    6.0  185.0

# %% [markdown]
# ### Tallest Wide Receiver
# - Looks like the top 5 tallest WR were all the same height

# %%
data[data["Pos"] == "WR"].sort_values("Ht", ascending = False).head(5)
# Out:
#                Player Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 3618    DeAndre Brown  WR  78  233   4.59      29.0       20.0      117.0
# 1466   Clarence Moore  WR  78  211   4.55      34.0        NaN      122.0
# 4624  Brandon Coleman  WR  78  225   4.56      32.5       21.0        NaN
# 2364    Aaron Fairooz  WR  78  209   4.49      36.0        NaN      125.0
# 2568     Matt Trannon  WR  78  216   4.57      36.5       13.0      118.0
#
#       Cone  Shuttle  Year    Pfr_ID   AV              Team  Round   Pick
# 3618  6.93     4.33  2011       NaN  0.0               NaN    NaN    NaN
# 1466  6.84     4.16  2004  MoorCl00  2.0  Baltimore Ravens    6.0  199.0
# 4624  7.33     4.51  2014  ColeBr00  6.0               NaN    NaN    NaN
# 2364  6.89     4.27  2007       NaN  0.0               NaN    NaN    NaN
# 2568  7.09     4.34  2007       NaN  0.0               NaN    NaN    NaN

# %% [markdown]
# ### Fastest Edge Rusher
# - Leon Jacobs hold the fastest time for the Edge position

# %%
data[data["Pos"] == "EDGE"].sort_values("Forty").head()
# Out:
#                Player   Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 6033      Leon Jacobs  EDGE  75  246   4.48      34.5       26.0      122.0
# 5930   Lorenzo Carter  EDGE  78  250   4.50      36.0        NaN      130.0
# 6162       Josh Sweat  EDGE  76  251   4.53      39.5        NaN      124.0
# 6049  Peter Kalambayi  EDGE  75  252   4.57      34.0       19.0      121.0
# 6058    Harold Landry  EDGE  75  252   4.64      36.0       24.0      119.0
#
#       Cone  Shuttle  Year    Pfr_ID   AV Team  Round  Pick
# 6033  7.14     4.44  2018       NaN  0.0  NaN    NaN   NaN
# 5930   NaN      NaN  2018  CartLo01  0.0  NaN    NaN   NaN
# 6162   NaN     4.28  2018  SweaJo00  0.0  NaN    NaN   NaN
# 6049  7.13     4.36  2018       NaN  0.0  NaN    NaN   NaN
# 6058  6.88     4.19  2018  LandHa00  0.0  NaN    NaN   NaN

# %% [markdown]
# ### Fastest Shuttle - RB
# - Donte Hall to be the fastest RB in shuttle drill

# %%
data[data["Pos"] == "RB"].sort_values("Shuttle").head()
# Out:
#               Player Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 123      Dante' Hall  RB  68  191   4.44      38.0       18.0      123.0
# 4157    Chris Rainey  RB  68  180   4.36      36.5       16.0      120.0
# 168    Curtis Keaton  RB  70  214   4.41      41.5       23.0      131.0
# 898      Josh Scobey  RB  71  218   4.42      40.5       21.0      124.0
# 4902  Ameer Abdullah  RB  69  205   4.60      42.5       24.0      130.0
#
#       Cone  Shuttle  Year    Pfr_ID    AV                 Team  Round   Pick
# 123   6.62     3.82  2000       NaN   0.0                  NaN    NaN    NaN
# 4157  6.50     3.93  2012  RainCh00   1.0  Pittsburgh Steelers    5.0  159.0
# 168   6.82     3.93  2000  KeatCu00   0.0   Cincinnati Bengals    4.0   97.0
# 898   6.96     3.93  2002  ScobJo00   3.0    Arizona Cardinals    6.0  185.0
# 4902  6.79     3.95  2015  AbduAm00  11.0        Detroit Lions    2.0   54.0

# %% [markdown]
# ### VIsualizations
# - Will use the data and seaborn to create visualizations on data
# - Bench press increases with the weight

# %%
plt.figure( figsize = (16,6))
plt.scatter(data["Wt"], data["BenchReps"], alpha= 0.4)

# %% [markdown]
# ### 40yard dash For a wide receiver weighing over 240

# %%
data[(data["Pos"] == "WR") & (data["Wt"] > 240)].set_index("Player")["Forty"].plot( figsize = (16,6), marker = "o")

# %% [markdown]
# ### Biggest Tight end over the last 18 years
# - Find the player that fit this credential
# - look at the top 5 tight ends in terms of weight over the years

# %% [markdown]
# #### Jason peters was the largest over the past 18 years

# %%
data[data["Pos"] == "TE"].set_index("Player").sort_values("Wt", ascending = False).head(5)["Wt"].plot(kind = "bar")

# %%
sns.pairplot(data)

# %% [markdown]
# ### THe above plot shows us that there is a stron negative coorelation between the Broard Jump and the Cone and shuttle Drill. This will alo mean that there is a strong positive coorelation between the cone an the shuttle drill which we can see above
