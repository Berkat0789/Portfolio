# %% [markdown]
# ## The World trade project is to look at daa compiled from https://www.census.gov/foreign-trade/statistics/country/sitc/index.html to evaluate volume of trade during economic crises. The focus will be, but not limited to, before and after the 2008 economic crisis as well as the 2020 Covid-19 crisis. The data used will be from Standard International Trade Classification (SITC) 1996-Present from link above.

# %% [markdown]
# ### Analysis will consist of all countries excluding the USA. We will be looking at all foreign countries using a SITC and the product classification associated

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1 = pd.read_excel("resources/sitc19614digit.xlsx")

# %%
data2 = pd.read_excel("resources/sitc115presdigit.xlsx")

# %%
import_export_data = pd.concat([data1,data2])

# %% [markdown]
# ### Inspect Data
# - We will need to convert the dates to a date time object to do time series analysis

# %%
import_export_data["Year"] = pd.to_datetime(import_export_data["Year"].astype(str))
import_export_data["Year"] = [x.year for x in import_export_data["Year"]]

# %% [markdown]
# ### Initial Analysis of all Foreign Countries

# %%
World_Exports_for_class = import_export_data.pivot_table(index="Year", columns=["sitc_sdesc"], values="ExportsFASValueBasisYtdDec")

# %%
World_Exports_for_class.head()
# Out:
# sitc_sdesc  ANIMAL AND VEGETABLE OILS, FATS AND WAXES  BEVERAGES AND TOBACCO  \
# Year
# 1996                                     2.527042e+07           8.916449e+07
# 1997                                     2.858285e+07           8.669811e+07
# 1998                                     3.651809e+07           8.655377e+07
# 1999                                     2.448895e+07           7.392739e+07
# 2000                                     1.893503e+07           7.663835e+07
#
# sitc_sdesc  CHEMICALS AND RELATED PRODUCTS  \
# Year
# 1996                          5.854054e+08
# 1997                          6.681758e+08
# 1998                          6.240551e+08
# 1999                          6.604481e+08
# 2000                          7.678331e+08
#
# sitc_sdesc  COMMODITIES & TRANSACTIONS NOT CLASSIFIED ELSEWHER  \
# Year
# 1996                                             2.297113e+08
# 1997                                             2.336435e+08
# 1998                                             2.316020e+08
# 1999                                             2.363469e+08
# 2000                                             2.597252e+08
#
# sitc_sdesc  CRUDE MATERIALS, INEDIBLE, EXCEPT FUELS  FOOD AND LIVE ANIMALS  \
# Year
# 1996                                   3.074698e+08           4.200759e+08
# 1997                                   3.111439e+08           3.718538e+08
# 1998                                   2.489041e+08           3.452065e+08
# 1999                                   2.302631e+08           3.540455e+08
# 2000                                   2.738850e+08           3.531855e+08
#
# sitc_sdesc  MACHINERY AND TRANSPORT EQUIPMENT  \
# Year
# 1996                             2.697624e+09
# 1997                             3.120713e+09
# 1998                             3.197932e+09
# 1999                             3.266546e+09
# 2000                             3.599997e+09
#
# sitc_sdesc  MANUFACTURED GOODS CLASSIFIED CHIEFLY BY MATERIAL  \
# Year
# 1996                                             5.139457e+08
# 1997                                             5.713509e+08
# 1998                                             5.567965e+08
# 1999                                             5.676440e+08
# 2000                                             6.514931e+08
#
# sitc_sdesc  MINERAL FUELS, LUBRICANTS AND RELATED MATERIALS  \
# Year
# 1996                                           1.472913e+08
# 1997                                           1.493715e+08
# 1998                                           1.198785e+08
# 1999                                           1.147533e+08
# 2000                                           1.551131e+08
#
# sitc_sdesc  MISCELLANEOUS MANUFACTURED ARTICLES
# Year
# 1996                               6.402944e+08
# 1997                               7.029950e+08
# 1998                               7.115086e+08
# 1999                               7.288387e+08
# 2000                               8.138314e+08

# %% [markdown]
# ### Annual growth for each Classificaiton (Export).
#
# - Below is each clasification for Imported and Exported Products from 1996 to 2020. We will look at How COVID 19 has effected each Sector. From initial observation we can see every sector has been effected by the COVID-19 outbreak. We Can also see the the 2008 crisis effect on the Import Export Market
# - Another observation is that we can see all sectors were effected by something in 2016 except beverags and tobacco. The assumption is the Election Year with Donald Trump coming into office.

# %%
fig, axes = plt.subplots(5,2, figsize = (16,15))
axes[0,0].plot(World_Exports_for_class["ANIMAL AND VEGETABLE OILS, FATS AND WAXES"], marker = "o", mfc = "r")
axes[0,0].set_title("ANIMAL AND VEGETABLE OILS, FATS AND WAXES")
axes[0,1].plot(World_Exports_for_class["BEVERAGES AND TOBACCO"], marker = "o", mfc = "brown")
axes[0,1].set_title("BEVERAGES AND TOBACCO")
axes[1,0].plot(World_Exports_for_class["CHEMICALS AND RELATED PRODUCTS"], marker = "o", mfc = "black")
axes[1,0].set_title("CHEMICALS AND RELATED PRODUCTS")
axes[1,1].plot(World_Exports_for_class["COMMODITIES & TRANSACTIONS NOT CLASSIFIED ELSEWHER"], marker = "o", mfc = "y")
axes[1,1].set_title("COMMODITIES & TRANSACTIONS NOT CLASSIFIED ELSEWHER")
axes[2,0].plot(World_Exports_for_class["CRUDE MATERIALS, INEDIBLE, EXCEPT FUELS"], marker = "o", mfc= "orange")
axes[2,0].set_title("CRUDE MATERIALS, INEDIBLE, EXCEPT FUELS")
axes[2,1].plot(World_Exports_for_class["FOOD AND LIVE ANIMALS"], marker = "o", mfc = "y", c = "black")
axes[2,1].set_title("FOOD AND LIVE ANIMALS")
axes[3,0].plot(World_Exports_for_class["MACHINERY AND TRANSPORT EQUIPMENT"], marker = "o", c = "g", mfc = "r")
axes[3,0].set_title("MACHINERY AND TRANSPORT EQUIPMENT")
axes[3,1].plot(World_Exports_for_class["MANUFACTURED GOODS CLASSIFIED CHIEFLY BY MATERIAL"], marker = "o", mfc = "black", c = "r")
axes[3,1].set_title("MANUFACTURED GOODS CLASSIFIED CHIEFLY BY MATERIAL")
axes[4,0].plot(World_Exports_for_class["MINERAL FUELS, LUBRICANTS AND RELATED MATERIALS"], marker = "o", c = "y", mfc = "r")
axes[4,0].set_title("MINERAL FUELS, LUBRICANTS AND RELATED MATERIALS")
axes[4,1].plot(World_Exports_for_class["MISCELLANEOUS MANUFACTURED ARTICLES"], marker = "o", c = "brown", mfc = "white")
axes[4,1].set_title("MISCELLANEOUS MANUFACTURED ARTICLES")
plt.tight_layout();

# %% [markdown]
# ### Export - country Leaders
# - We will be looking at the top 10 leaders in Export and the time series performance
# - Looks like canada is the leader in exports averaging approximately 20B annually
# - We will analyze the top 3 countries for export and see what their top exports are and how those products are performing currently

# %%
import_export_data.groupby("Country").mean().drop("World Total").sort_values("ExportsFASValueBasisYtdDec"
                                , ascending =False)["ExportsFASValueBasisYtdDec"].head(10).plot(kind = "bar",
                                    cmap ="coolwarm", figsize = (16,6))
plt.title("Top Ten Countries for Export");

# %% [markdown]
# ## Canada
# - Canada Top Exported Product is Machinery and Transport Equipment at approximately 140B in 2015
# - We can se a groth in the Minerals Fuel..Sector between 2010 and 2015 which as effected by election in 2016(assuming) and Covid-19 in 2020

# %%
canada = import_export_data[import_export_data["Country"] == "Canada"].pivot_table(index = "Year"
                        , columns = ["sitc_sdesc"], values = "ExportsFASValueBasisYtdDec")

# %%
canada.plot(figsize = (20,10), marker = "o", cmap = "magma")
plt.title("Canada Export Sector Performance");

# %% [markdown]
# #### Canada -> MACHINERY AND TRANSPORT EQUIPMENT

# %%
plt.figure(figsize = (16,6))
sns.barplot(x = canada.index, y = "MACHINERY AND TRANSPORT EQUIPMENT", data=canada)

# %% [markdown]
# ### MEXICO -> Exports

# %%
Mexico = import_export_data[import_export_data["Country"] == "Mexico"].pivot_table(index = "Year"
                        , columns = ["sitc_sdesc"], values = "ExportsFASValueBasisYtdDec")

# %%
Mexico.head()
# Out:
# sitc_sdesc  ANIMAL AND VEGETABLE OILS, FATS AND WAXES  BEVERAGES AND TOBACCO  \
# Year
# 1996                                        323184811               80361634
# 1997                                        374856417               82459238
# 1998                                        460098571               82864193
# 1999                                        359651658              111424250
# 2000                                        303192523              126707672
#
# sitc_sdesc  CHEMICALS AND RELATED PRODUCTS  \
# Year
# 1996                            5175365503
# 1997                            6343319650
# 1998                            6873589007
# 1999                            7186763229
# 2000                            8944484120
#
# sitc_sdesc  COMMODITIES & TRANSACTIONS NOT CLASSIFIED ELSEWHER  \
# Year
# 1996                                               2283256362
# 1997                                               3018616085
# 1998                                               3638883529
# 1999                                               4114968444
# 2000                                               5019717206
#
# sitc_sdesc  CRUDE MATERIALS, INEDIBLE, EXCEPT FUELS  FOOD AND LIVE ANIMALS  \
# Year
# 1996                                     2479808910             3575427206
# 1997                                     2956001547             3073991062
# 1998                                     3072742325             3840168010
# 1999                                     2602750668             3885241614
# 2000                                     3137724743             4620568892
#
# sitc_sdesc  MACHINERY AND TRANSPORT EQUIPMENT  \
# Year
# 1996                              26613323153
# 1997                              35810339454
# 1998                              38839436677
# 1999                              43591980282
# 2000                              57143573364
#
# sitc_sdesc  MANUFACTURED GOODS CLASSIFIED CHIEFLY BY MATERIAL  \
# Year
# 1996                                               8229958568
# 1997                                               9319174933
# 1998                                              10790007645
# 1999                                              12408501676
# 2000                                              15789532692
#
# sitc_sdesc  MINERAL FUELS, LUBRICANTS AND RELATED MATERIALS  \
# Year
# 1996                                             1524004588
# 1997                                             2005829009
# 1998                                             1773182067
# 1999                                             2268279064
# 2000                                             4303368528
#
# sitc_sdesc  MISCELLANEOUS MANUFACTURED ARTICLES
# Year
# 1996                                 6476132163
# 1997                                 8393723044
# 1998                                 9639115448
# 1999                                10336268197
# 2000                                12332008236

# %%
Mexico.plot(figsize = (20,10), marker = "o")
plt.title("Mexico Export Sector Performance");

# %%
plt.figure(figsize = (16,6))
sns.barplot(x = Mexico.index, y = "MACHINERY AND TRANSPORT EQUIPMENT", data=canada, palette="ocean")

# %% [markdown]
# ## China ->  Exports
# - Machinery and Transport Equipment leads the export market as well, followed by Crude Materials..

# %%
China = import_export_data[import_export_data["Country"] == "China"].pivot_table(index = "Year"
                        , columns = ["sitc_sdesc"], values = "ExportsFASValueBasisYtdDec")

# %%
China.head()
# Out:
# sitc_sdesc  ANIMAL AND VEGETABLE OILS, FATS AND WAXES  BEVERAGES AND TOBACCO  \
# Year
# 1996                                        113628845                3293975
# 1997                                        169072980                8726700
# 1998                                        320554292               12416277
# 1999                                         74329728               10822767
# 2000                                         20903925                4927616
#
# sitc_sdesc  CHEMICALS AND RELATED PRODUCTS  \
# Year
# 1996                            1727302111
# 1997                            1935288086
# 1998                            1972944931
# 1999                            2089319240
# 2000                            2325369950
#
# sitc_sdesc  COMMODITIES & TRANSACTIONS NOT CLASSIFIED ELSEWHER  \
# Year
# 1996                                                157955685
# 1997                                                153748739
# 1998                                                205582701
# 1999                                                209332953
# 2000                                                222761656
#
# sitc_sdesc  CRUDE MATERIALS, INEDIBLE, EXCEPT FUELS  FOOD AND LIVE ANIMALS  \
# Year
# 1996                                     1888546294              774024218
# 1997                                     1639634369              399515179
# 1998                                     1076487379              487149535
# 1999                                     1178184694              325980983
# 2000                                     2566502345              472945286
#
# sitc_sdesc  MACHINERY AND TRANSPORT EQUIPMENT  \
# Year
# 1996                               5570011536
# 1997                               6521832612
# 1998                               8238766083
# 1999                               7148722265
# 2000                               8067817619
#
# sitc_sdesc  MANUFACTURED GOODS CLASSIFIED CHIEFLY BY MATERIAL  \
# Year
# 1996                                                789615148
# 1997                                                810298405
# 1998                                                858504543
# 1999                                                900521891
# 2000                                               1271889048
#
# sitc_sdesc  MINERAL FUELS, LUBRICANTS AND RELATED MATERIALS  \
# Year
# 1996                                               67593881
# 1997                                              231680914
# 1998                                              127233515
# 1999                                              122529632
# 2000                                               59768815
#
# sitc_sdesc  MISCELLANEOUS MANUFACTURED ARTICLES
# Year
# 1996                                  885948935
# 1997                                  935618514
# 1998                                  958313518
# 1999                                 1057933228
# 2000                                 1240143089

# %%
China.plot(figsize = (20,10), marker = "o", cmap = "magma")
plt.title("China Export Sector Performance");

# %%
plt.figure(figsize = (16,6))
sns.barplot(x = China.index, y = "MACHINERY AND TRANSPORT EQUIPMENT", data=canada, palette="summer")

# %% [markdown]
# ### Annual change for total Exports
# - Total Exports are already do 85% in 2020. Has never happened since 1996

# %%
Worlds_Export_Annual = import_export_data.groupby("Year").sum()

# %%
Worlds_Export_Annual["Annual Export pct Change"] = Worlds_Export_Annual["ExportsFASValueBasisYtdDec"].pct_change()

# %%
Worlds_Export_Annual["Annual Export pct Change"].plot(kind = "bar", figsize = (16,6))

# %% [markdown]
# ### Import market will continue here
