# %% [markdown]
# ### Project overview
# - Your assigned to create a movel that will predict if a user wull click on an ad or not. The data you will be given will be data from past user who have or have not clicked on a ad. This data will also provide you information of the user and certain characteristics of that user. Your target is a one hot encoding of clicked and not clicked (1,2). Create am ode that will predict this accurately

# %% [markdown]
# ### Project approach
# - Initiailly what is known is that this will be a binary classification for the target.
# - Will create a modle that will predict the classification od clicked or not clicked
# - Will analyze the data and create visualizations to get better insight on the data

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
import coremltools

# %%
ad_data = pd.read_csv("resources/advertising.csv")

# %% [markdown]
# ### Data Overview
#  - Data set hace 100 data points with none missing, good start!
#  - we have 10 columns with "clicked on ad" being our target
#  - There are a few string columns we may need to analyze or drop since we cannot bass these into our model

# %%
ad_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %% [markdown]
# ### Seaborn Pair Plot - Features to clicks (Analysis)
# - Below is  a plot that tells us the relation to a feature and is corelation to the Target class(Clicked on ad)
# - As Age increases and more time is spent on the site the user is more likely to click on an ad
# - Users with a highw income are less likely to click on ad the more time they spend on the site
# - Users with a higher income are more likely to click on an ad as their dail internet usage increases

# %%
sns.pairplot(ad_data.drop(["Male"], axis = 1), hue = "Clicked on Ad", aspect=1.2, height=2)

# %% [markdown]
# ### Correlation Analysis
# - We will use this to find whnich features are related to each other and which are impacting the Target
# - We can see that Daily Time spent on site is inversely coorelated to the ad clicks
# - Also overall daily internet usage is inversely coorelated to the ad clicks
# - We can safely say that the more an indicvidul uses the computer the less likey they will click on an ad
# - The positive coorelation to ad clices appears to be the Age of the user,  will plot this below

# %%
ad_data.corr()
# Out:
#                           Daily Time Spent on Site       Age  Area Income  \
# Daily Time Spent on Site                  1.000000 -0.331513     0.310954
# Age                                      -0.331513  1.000000    -0.182605
# Area Income                               0.310954 -0.182605     1.000000
# Daily Internet Usage                      0.518658 -0.367209     0.337496
# Male                                     -0.018951 -0.021044     0.001322
# Clicked on Ad                            -0.748117  0.492531    -0.476255
#
#                           Daily Internet Usage      Male  Clicked on Ad
# Daily Time Spent on Site              0.518658 -0.018951      -0.748117
# Age                                  -0.367209 -0.021044       0.492531
# Area Income                           0.337496  0.001322      -0.476255
# Daily Internet Usage                  1.000000  0.028012      -0.786539
# Male                                  0.028012  1.000000      -0.038027
# Clicked on Ad                        -0.786539 -0.038027       1.000000

# %% [markdown]
# ### Coorelation to Target

# %%
ad_data.corr()["Clicked on Ad"][:-1].plot(kind = "bar", figsize = (16,6))

# %% [markdown]
# # Analysis Continued

# %%
ad_data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# 1  2016-04-04 01:39:02              0
# 2  2016-03-13 20:35:42              0
# 3  2016-01-10 02:31:19              0
# 4  2016-06-03 03:36:18              0

# %% [markdown]
# ### Male to Famale
# - We have a pretty evenly distributed data set relation to sex. Our results will be a be less scued to one sex

# %%
sns.countplot("Male", data=ad_data)

# %% [markdown]
# ### Age range for male and female
# - Age to sex is an even distribution as well

# %%
sns.boxplot(x = "Male", y = "Age", data=ad_data, palette="rainbow")

# %% [markdown]
# ### Time stamp Analysis
# - Will convert the TimeStamp column to a pandas data time and look at the days users are more likely to click on an ad

# %%
ad_data["Timestamp"] = pd.to_datetime(ad_data["Timestamp"])

# %%
ad_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   datetime64[ns]
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 78.2+ KB

# %% [markdown]
# ### Feature generation of the days for clicked

# %%
ad_data["day"] = ad_data['Timestamp'].apply(lambda x: x.dayofweek)

# %%
ad_data
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# 0       Cloned 5thgeneration orchestration     Wrightburgh     0
# 1       Monitored national standardization       West Jodi     1
# 2         Organic bottom-line service-desk        Davidton     0
# 3    Triple-buffered reciprocal time-frame  West Terrifurt     1
# 4            Robust logistical utilization    South Manuel     0
# ..                                     ...             ...   ...
# 995          Fundamental modular algorithm       Duffystad     1
# 996        Grass-roots cohesive monitoring     New Darlene     1
# 997           Expanded intangible solution   South Jessica     1
# 998   Proactive bandwidth-monitored policy     West Steven     0
# 999        Virtual 5thgeneration emulation     Ronniemouth     0
#
#                     Country           Timestamp  Clicked on Ad  day
# 0                   Tunisia 2016-03-27 00:53:11              0    6
# 1                     Nauru 2016-04-04 01:39:02              0    0
# 2                San Marino 2016-03-13 20:35:42              0    6
# 3                     Italy 2016-01-10 02:31:19              0    6
# 4                   Iceland 2016-06-03 03:36:18              0    4
# ..                      ...                 ...            ...  ...
# 995                 Lebanon 2016-02-11 21:49:00              1    3
# 996  Bosnia and Herzegovina 2016-04-22 02:07:01              1    4
# 997                Mongolia 2016-02-01 17:24:57              1    0
# 998               Guatemala 2016-03-24 02:35:54              0    3
# 999                  Brazil 2016-06-03 21:43:21              1    4
#
# [1000 rows x 11 columns]

# %% [markdown]
# ### Day of week analysis
# - Appears more users clickd on an ad on tuesday. But also less users clidked on Thursday

# %%
plt.figure(figsize=(16,6))
sns.countplot(x = "day", data=ad_data, hue="Clicked on Ad", palette="magma")

# %% [markdown]
# ### Male to female analysis for dat of the week
# - Appears the Males are a little less likely to click on an ad on Friday

# %%
plt.figure(figsize=(16,6))
sns.boxplot(x = "Clicked on Ad", y = "day", data=ad_data, hue="Male")

# %% [markdown]
# ## Preprocessing
# - There is still room for analysis but we will take a deeper dive into the data to start to train our model
# - Lets begin by removing the Values that we is not need and will not work with our model
# - We will remove the Topic Line, Though we could check is the lenth of the ad topic line effects the clicks
# - Will also remove the City, COuntry and Timestamp(since we have the day)

# %%
ad_data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#             Timestamp  Clicked on Ad  day
# 0 2016-03-27 00:53:11              0    6
# 1 2016-04-04 01:39:02              0    0
# 2 2016-03-13 20:35:42              0    6
# 3 2016-01-10 02:31:19              0    6
# 4 2016-06-03 03:36:18              0    4

# %%
ad_data.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad', 'day'],
#       dtype='object')

# %%
ad_data.drop(['Ad Topic Line', "Country", 'City','Timestamp'], axis=1, inplace=True)

# %% [markdown]
# ### Finalized
# - Appears we have the data we need to complete our model

# %%
ad_data
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                       68.95   35     61833.90                256.09     0
# 1                       80.23   31     68441.85                193.77     1
# 2                       69.47   26     59785.94                236.50     0
# 3                       74.15   29     54806.18                245.89     1
# 4                       68.37   35     73889.99                225.58     0
# ..                        ...  ...          ...                   ...   ...
# 995                     72.97   30     71384.57                208.58     1
# 996                     51.30   45     67782.17                134.42     1
# 997                     51.63   51     42415.72                120.37     1
# 998                     55.55   19     41920.79                187.95     0
# 999                     45.01   26     29875.80                178.35     0
#
#      Clicked on Ad  day
# 0                0    6
# 1                0    0
# 2                0    6
# 3                0    6
# 4                0    4
# ..             ...  ...
# 995              1    3
# 996              1    4
# 997              1    0
# 998              0    3
# 999              1    4
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### Training testing splitting
# - Will seperated 20% of the data into our test set

# %%
from sklearn.model_selection import train_test_split

# %%
X = ad_data.drop("Clicked on Ad", axis=1).values
y = ad_data["Clicked on Ad"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
X_train.shape
# Out:
# (700, 6)

# %%
X_test.shape
# Out:
# (300, 6)

# %% [markdown]
# ### Scaling the data
# - WE will scale the data so the the full range of all points are considered and no one outlier is impacting the outcome of the model

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scalar = MinMaxScaler()

# %%
X_train = scalar.fit_transform(X_train)

# %%
X_test = scalar.transform(X_test)

# %% [markdown]
# ### Model Preparation
# - Wll add an early stopping callback to the model so that we prevent overtraining

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
stop = EarlyStopping(monitor="val_loss", mode="min", patience=20)

# %% [markdown]
# ### Model Creation
# - Will use a Sequential ANN for the model with a Few Dense Layer
# - Activation function will be a RELU
# - Outout layer will be a Sigmoid function
# - Loss will be a binary_crossentropy function
# - Optimizer will be Adam
# - If the model is not as accurate we will add a few dropout layers

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
model = Sequential()
model.add(Dense(units = 30, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(units = 20, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(units = 10, activation = "relu"))
model.add(Dense(units = 1, activation = "sigmoid"))
model.compile(loss = "binary_crossentropy", optimizer = "adam")

# %% [markdown]
# ### Fitting the model

# %%
model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs=300, callbacks=[stop])
# Out:
# Train on 700 samples, validate on 300 samples
# Epoch 1/300
# 700/700 [==============================] - 3s 4ms/sample - loss: 0.7321 - val_loss: 0.6815
# Epoch 2/300
# 700/700 [==============================] - 0s 194us/sample - loss: 0.7029 - val_loss: 0.6762
# Epoch 3/300
# 700/700 [==============================] - 0s 191us/sample - loss: 0.6775 - val_loss: 0.6624
# Epoch 4/300
# 700/700 [==============================] - 0s 192us/sample - loss: 0.6615 - val_loss: 0.6375
# Epoch 5/300
# 700/700 [==============================] - 0s 192us/sample - loss: 0.6396 - val_loss: 0.5896
# Epoch 6/300
# 700/700 [==============================] - 0s 191us/sample - loss: 0.6138 - val_loss: 0.5487
# Epoch 7/300
# 700/700 [==============================] - 0s 193us/sample - loss: 0.5765 - val_loss: 0.5064
# Epoch 8/300
# 700/700 [==============================] - 0s 193us/sample - loss: 0.5544 - val_loss: 0.4461
# Epoch 9/300
# 700/700 [==============================] - 0s 191us/sample - loss: 0.5021 - val_loss: 0.3907
# Epoch 10/300
# 700/700 [==============================] - 0s 192us/sample - loss: 0.4430 - val_loss: 0.3280
# Epoch 11/300
# 700/700 [==============================] - 0s 198us/sample - loss: 0.4122 - val_loss: 0.2884
# Epoch 12/300
# 700/700 [==============================] - 0s 188us/sample - loss: 0.3783 - val_loss: 0.2509
# Epoch 13/300
# 700/700 [==============================] - 0s 191us/sample - loss: 0.3490 - val_loss: 0.2277
# Epoch 14/300
# 700/700 [==============================] - 0s 192us/sample - loss: 0.3121 - val_loss: 0.2154
# Epoch 15/300
# 700/700 [==============================] - 0s 191us/sample - loss: 0.3082 - val_loss: 0.2026
# Epoch 16/300
# 700/700 [==============================] - 0s 189us/sample - loss: 0.2666 - val_loss: 0.1907
# Epoch 17/300
# 700/700 [==============================] - 0s 187us/sample - loss: 0.2275 - val_loss: 0.1881
# Epoch 18/300
# 700/700 [==============================] - 0s 199us/sample - loss: 0.2431 - val_loss: 0.1804
# Epoch 19/300
# 700/700 [==============================] - 0s 203us/sample - loss: 0.2381 - val_loss: 0.1751
# Epoch 20/300
# 700/700 [==============================] - 0s 190us/sample - loss: 0.2312 - val_loss: 0.1717
# Epoch 21/300
# 700/700 [==============================] - 0s 189us/sample - loss: 0.2079 - val_loss: 0.1742
# Epoch 22/300
# 700/700 [==============================] - 0s 191us/sample - loss: 0.2171 - val_loss: 0.1707
# Epoch 23/300
# 700/700 [==============================] - 0s 192us/sample - loss: 0.2015 - val_loss: 0.1686
# Epoch 24/300
# 700/700 [==============================] - 0s 189us/sample - loss: 0.2170 - val_loss: 0.1638
# Epoch 25/300
# 700/700 [==============================] - 0s 190us/sample - loss: 0.1903 - val_loss: 0.1615
# Epoch 26/300
# 700/700 [==============================] - 0s 193us/sample - loss: 0.2053 - val_loss: 0.1607
# Epoch 27/300
# 700/700 [==============================] - 0s 190us/sample - loss: 0.1628 - val_loss: 0.1576
# Epoch 28/300
# 700/700 [==============================] - 0s 189us/sample - loss: 0.1916 - val_loss: 0.1568
# Epoch 29/300
# 700/700 [==============================] - 0s 194us/sample - loss: 0.2059 - val_loss: 0.1553
# Epoch 30/300
# 700/700 [==============================] - 0s 191us/sample - loss: 0.1761 - val_loss: 0.1557
# Epoch 31/300
# 700/700 [==============================] - 0s 190us/sample - loss: 0.1838 - val_loss: 0.1549
# Epoch 32/300
# 700/700 [==============================] - 0s 189us/sample - loss: 0.1894 - val_loss: 0.1555
# Epoch 33/300
# 700/700 [==============================] - 0s 205us/sample - loss: 0.1610 - val_loss: 0.1549
# Epoch 34/300
# 700/700 [==============================] - 0s 221us/sample - loss: 0.1752 - val_loss: 0.1535
# Epoch 35/300
# 700/700 [==============================] - 0s 197us/sample - loss: 0.1671 - val_loss: 0.1560
# Epoch 36/300
# 700/700 [==============================] - 0s 191us/sample - loss: 0.1686 - val_loss: 0.1557
# Epoch 37/300
# 700/700 [==============================] - 0s 241us/sample - loss: 0.1692 - val_loss: 0.1560
# Epoch 38/300
# 700/700 [==============================] - 0s 216us/sample - loss: 0.1506 - val_loss: 0.1561
# Epoch 39/300
# 700/700 [==============================] - 0s 226us/sample - loss: 0.1560 - val_loss: 0.1552
# Epoch 40/300
# 700/700 [==============================] - 0s 208us/sample - loss: 0.1511 - val_loss: 0.1557
# Epoch 41/300
# 700/700 [==============================] - 0s 210us/sample - loss: 0.1716 - val_loss: 0.1538
# Epoch 42/300
# 700/700 [==============================] - 0s 208us/sample - loss: 0.1483 - val_loss: 0.1491
# Epoch 43/300
# 700/700 [==============================] - 0s 191us/sample - loss: 0.1527 - val_loss: 0.1481
# Epoch 44/300
# 700/700 [==============================] - 0s 197us/sample - loss: 0.1493 - val_loss: 0.1472
# Epoch 45/300
# 700/700 [==============================] - 0s 188us/sample - loss: 0.1395 - val_loss: 0.1484
# Epoch 46/300
# 700/700 [==============================] - 0s 190us/sample - loss: 0.1465 - val_loss: 0.1542
# Epoch 47/300
# 700/700 [==============================] - 0s 189us/sample - loss: 0.1541 - val_loss: 0.1566
# Epoch 48/300
# 700/700 [==============================] - 0s 189us/sample - loss: 0.1418 - val_loss: 0.1589
# Epoch 49/300
# 700/700 [==============================] - 0s 191us/sample - loss: 0.1658 - val_loss: 0.1531
# Epoch 50/300
# 700/700 [==============================] - 0s 189us/sample - loss: 0.1398 - val_loss: 0.1465
# Epoch 51/300
# 700/700 [==============================] - 0s 191us/sample - loss: 0.1232 - val_loss: 0.1509
# Epoch 52/300
# 700/700 [==============================] - 0s 188us/sample - loss: 0.1443 - val_loss: 0.1535
# Epoch 53/300
# 700/700 [==============================] - 0s 189us/sample - loss: 0.1354 - val_loss: 0.1520
# Epoch 54/300
# 700/700 [==============================] - 0s 194us/sample - loss: 0.1477 - val_loss: 0.1482
# Epoch 55/300
# 700/700 [==============================] - 0s 228us/sample - loss: 0.1389 - val_loss: 0.1414
# Epoch 56/300
# 700/700 [==============================] - 0s 190us/sample - loss: 0.1311 - val_loss: 0.1389
# Epoch 57/300
# 700/700 [==============================] - 0s 192us/sample - loss: 0.1346 - val_loss: 0.1390
# Epoch 58/300
# 700/700 [==============================] - 0s 216us/sample - loss: 0.1249 - val_loss: 0.1470
# Epoch 59/300
# 700/700 [==============================] - 0s 205us/sample - loss: 0.1340 - val_loss: 0.1420
# Epoch 60/300
# 700/700 [==============================] - 0s 209us/sample - loss: 0.1241 - val_loss: 0.1431
# Epoch 61/300
# 700/700 [==============================] - 0s 203us/sample - loss: 0.1406 - val_loss: 0.1441
# Epoch 62/300
# 700/700 [==============================] - 0s 189us/sample - loss: 0.1278 - val_loss: 0.1464
# Epoch 63/300
# 700/700 [==============================] - 0s 205us/sample - loss: 0.1298 - val_loss: 0.1472
# Epoch 64/300
# 700/700 [==============================] - 0s 216us/sample - loss: 0.1253 - val_loss: 0.1466
# Epoch 65/300
# 700/700 [==============================] - 0s 204us/sample - loss: 0.1309 - val_loss: 0.1418
# Epoch 66/300
# 700/700 [==============================] - 0s 204us/sample - loss: 0.1360 - val_loss: 0.1439
# Epoch 67/300
# 700/700 [==============================] - 0s 221us/sample - loss: 0.1223 - val_loss: 0.1415
# Epoch 68/300
# 700/700 [==============================] - 0s 205us/sample - loss: 0.1313 - val_loss: 0.1387
# Epoch 69/300
# 700/700 [==============================] - 0s 201us/sample - loss: 0.1258 - val_loss: 0.1402
# Epoch 70/300
# 700/700 [==============================] - 0s 202us/sample - loss: 0.1124 - val_loss: 0.1419
# Epoch 71/300
# 700/700 [==============================] - 0s 194us/sample - loss: 0.1035 - val_loss: 0.1413
# Epoch 72/300
# 700/700 [==============================] - 0s 197us/sample - loss: 0.1197 - val_loss: 0.1429
# Epoch 73/300
# 700/700 [==============================] - 0s 194us/sample - loss: 0.1317 - val_loss: 0.1399
# Epoch 74/300
# 700/700 [==============================] - 0s 195us/sample - loss: 0.1163 - val_loss: 0.1377
# Epoch 75/300
# 700/700 [==============================] - 0s 200us/sample - loss: 0.1327 - val_loss: 0.1376
# Epoch 76/300
# 700/700 [==============================] - 0s 202us/sample - loss: 0.1127 - val_loss: 0.1373
# Epoch 77/300
# 700/700 [==============================] - 0s 198us/sample - loss: 0.1132 - val_loss: 0.1354
# Epoch 78/300
# 700/700 [==============================] - 0s 195us/sample - loss: 0.1270 - val_loss: 0.1383
# Epoch 79/300
# 700/700 [==============================] - 0s 199us/sample - loss: 0.1173 - val_loss: 0.1379
# Epoch 80/300
# 700/700 [==============================] - 0s 201us/sample - loss: 0.1286 - val_loss: 0.1396
# Epoch 81/300
# 700/700 [==============================] - 0s 201us/sample - loss: 0.1049 - val_loss: 0.1386
# Epoch 82/300
# 700/700 [==============================] - 0s 207us/sample - loss: 0.1128 - val_loss: 0.1404
# Epoch 83/300
# 700/700 [==============================] - 0s 200us/sample - loss: 0.1030 - val_loss: 0.1388
# Epoch 84/300
# 700/700 [==============================] - 0s 211us/sample - loss: 0.1108 - val_loss: 0.1374
# Epoch 85/300
# 700/700 [==============================] - 0s 210us/sample - loss: 0.1270 - val_loss: 0.1398
# Epoch 86/300
# 700/700 [==============================] - 0s 201us/sample - loss: 0.1199 - val_loss: 0.1338
# Epoch 87/300
# 700/700 [==============================] - 0s 197us/sample - loss: 0.0987 - val_loss: 0.1332
# Epoch 88/300
# 700/700 [==============================] - 0s 216us/sample - loss: 0.1056 - val_loss: 0.1330
# Epoch 89/300
# 700/700 [==============================] - 0s 210us/sample - loss: 0.1179 - val_loss: 0.1306
# Epoch 90/300
# 700/700 [==============================] - 0s 214us/sample - loss: 0.1244 - val_loss: 0.1351
# Epoch 91/300
# 700/700 [==============================] - 0s 209us/sample - loss: 0.1080 - val_loss: 0.1333
# Epoch 92/300
# 700/700 [==============================] - 0s 206us/sample - loss: 0.1166 - val_loss: 0.1376
# Epoch 93/300
# 700/700 [==============================] - 0s 203us/sample - loss: 0.1148 - val_loss: 0.1371
# Epoch 94/300
# 700/700 [==============================] - 0s 204us/sample - loss: 0.1075 - val_loss: 0.1303
# Epoch 95/300
# 700/700 [==============================] - 0s 206us/sample - loss: 0.0904 - val_loss: 0.1313
# Epoch 96/300
# 700/700 [==============================] - 0s 203us/sample - loss: 0.1024 - val_loss: 0.1348
# Epoch 97/300
# 700/700 [==============================] - 0s 196us/sample - loss: 0.1124 - val_loss: 0.1361
# Epoch 98/300
# 700/700 [==============================] - 0s 197us/sample - loss: 0.1075 - val_loss: 0.1346
# Epoch 99/300
# 700/700 [==============================] - 0s 223us/sample - loss: 0.0933 - val_loss: 0.1363
# Epoch 100/300
# 700/700 [==============================] - 0s 200us/sample - loss: 0.0966 - val_loss: 0.1336
# Epoch 101/300
# 700/700 [==============================] - 0s 207us/sample - loss: 0.0975 - val_loss: 0.1327
# Epoch 102/300
# 700/700 [==============================] - 0s 199us/sample - loss: 0.1057 - val_loss: 0.1362
# Epoch 103/300
# 700/700 [==============================] - 0s 202us/sample - loss: 0.1192 - val_loss: 0.1300
# Epoch 104/300
# 700/700 [==============================] - 0s 200us/sample - loss: 0.1029 - val_loss: 0.1330
# Epoch 105/300
# 700/700 [==============================] - 0s 202us/sample - loss: 0.0951 - val_loss: 0.1329
# Epoch 106/300
# 700/700 [==============================] - 0s 209us/sample - loss: 0.1042 - val_loss: 0.1362
# Epoch 107/300
# 700/700 [==============================] - 0s 203us/sample - loss: 0.0843 - val_loss: 0.1398
# Epoch 108/300
# 700/700 [==============================] - 0s 205us/sample - loss: 0.1118 - val_loss: 0.1403
# Epoch 109/300
# 700/700 [==============================] - 0s 203us/sample - loss: 0.1148 - val_loss: 0.1398
# Epoch 110/300
# 700/700 [==============================] - 0s 200us/sample - loss: 0.1053 - val_loss: 0.1404
# Epoch 111/300
# 700/700 [==============================] - 0s 197us/sample - loss: 0.1013 - val_loss: 0.1324
# Epoch 112/300
# 700/700 [==============================] - 0s 193us/sample - loss: 0.0929 - val_loss: 0.1260
# Epoch 113/300
# 700/700 [==============================] - 0s 204us/sample - loss: 0.0964 - val_loss: 0.1295
# Epoch 114/300
# 700/700 [==============================] - 0s 204us/sample - loss: 0.1051 - val_loss: 0.1306
# Epoch 115/300
# 700/700 [==============================] - 0s 198us/sample - loss: 0.1022 - val_loss: 0.1265
# Epoch 116/300
# 700/700 [==============================] - 0s 210us/sample - loss: 0.0832 - val_loss: 0.1307
# Epoch 117/300
# 700/700 [==============================] - 0s 200us/sample - loss: 0.1203 - val_loss: 0.1287
# Epoch 118/300
# 700/700 [==============================] - 0s 196us/sample - loss: 0.1104 - val_loss: 0.1256
# Epoch 119/300
# 700/700 [==============================] - 0s 200us/sample - loss: 0.0953 - val_loss: 0.1221
# Epoch 120/300
# 700/700 [==============================] - 0s 208us/sample - loss: 0.0980 - val_loss: 0.1259
# Epoch 121/300
# 700/700 [==============================] - 0s 206us/sample - loss: 0.1004 - val_loss: 0.1270
# Epoch 122/300
# 700/700 [==============================] - 0s 203us/sample - loss: 0.1006 - val_loss: 0.1255
# Epoch 123/300
# 700/700 [==============================] - 0s 205us/sample - loss: 0.1065 - val_loss: 0.1272
# Epoch 124/300
# 700/700 [==============================] - 0s 205us/sample - loss: 0.1019 - val_loss: 0.1266
# Epoch 125/300
# 700/700 [==============================] - 0s 198us/sample - loss: 0.0811 - val_loss: 0.1360
# Epoch 126/300
# 700/700 [==============================] - 0s 195us/sample - loss: 0.0941 - val_loss: 0.1266
# Epoch 127/300
# 700/700 [==============================] - 0s 209us/sample - loss: 0.0969 - val_loss: 0.1276
# Epoch 128/300
# 700/700 [==============================] - 0s 213us/sample - loss: 0.0877 - val_loss: 0.1296
# Epoch 129/300
# 700/700 [==============================] - 0s 211us/sample - loss: 0.1171 - val_loss: 0.1308
# Epoch 130/300
# 700/700 [==============================] - 0s 209us/sample - loss: 0.0995 - val_loss: 0.1265
# Epoch 131/300
# 700/700 [==============================] - 0s 201us/sample - loss: 0.0989 - val_loss: 0.1318
# Epoch 132/300
# 700/700 [==============================] - 0s 200us/sample - loss: 0.0947 - val_loss: 0.1348
# Epoch 133/300
# 700/700 [==============================] - 0s 208us/sample - loss: 0.0923 - val_loss: 0.1400
# Epoch 134/300
# 700/700 [==============================] - 0s 207us/sample - loss: 0.0886 - val_loss: 0.1370
# Epoch 135/300
# 700/700 [==============================] - 0s 204us/sample - loss: 0.1001 - val_loss: 0.1324
# Epoch 136/300
# 700/700 [==============================] - 0s 199us/sample - loss: 0.1061 - val_loss: 0.1248
# Epoch 137/300
# 700/700 [==============================] - 0s 206us/sample - loss: 0.0896 - val_loss: 0.1249
# Epoch 138/300
# 700/700 [==============================] - 0s 209us/sample - loss: 0.0890 - val_loss: 0.1315
# Epoch 139/300
# 700/700 [==============================] - 0s 196us/sample - loss: 0.0822 - val_loss: 0.1308

# %% [markdown]
# ### model Training Preformance
#  -Model ttraining improved dramatically with the adddition to Dropout layers

# %%
pd.DataFrame(model.history.history).plot(figsize = (16,6))

# %% [markdown]
# ### Model Predictions
# - Will look at how accurate the model predicitons are using Sklearn's metrics

# %%
predictions = model.predict_classes(X_test)

# %% [markdown]
# ## Metrics
# - We get a pretty high precision on the model and this is what we want
# - We are looking at a 95% accuracy at training which is amazing
# - We now can predict 95% accuratly when a user will click on an ad

# %%
from sklearn.metrics import classification_report, confusion_matrix, explained_variance_score

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       146
#            1       0.97      0.94      0.96       154
#
#     accuracy                           0.96       300
#    macro avg       0.96      0.96      0.96       300
# weighted avg       0.96      0.96      0.96       300

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[142   4]
#  [  9 145]]

# %% [markdown]
# ### Explained Varience score
# - 80% explained variance tells us that the features explains 80% of the time a user clicks or does not click on an ad

# %%
print(explained_variance_score(y_test,predictions))
# Out:
# 0.8276552214908379

# %% [markdown]
# ### Testing model
# - We will pasds the model a random index without the target and see how it predicts. This will give us insite on how the model will behave when new data is passed in the future

# %%
from random import randint
random_index = randint(1,len(ad_data))
random_user = ad_data.drop("Clicked on Ad", axis=1).iloc[random_index]

# %% [markdown]
# ## New user
# - Will need to reshape (same as trianing data) the new user values to fit the data them model is expecting
# - Also scale the new data

# %%
X_train.shape
# Out:
# (700, 6)

# %%
new_user = scalar.transform(random_user.values.reshape(1,6))

# %% [markdown]
# ## New user predicitons

# %%
model.predict_classes(new_user)
# Out:
# array([[0]], dtype=int32)

# %% [markdown]
# ### True Value

# %%
ad_data.iloc[random_index]["Clicked on Ad"]
# Out:
# 0.0
